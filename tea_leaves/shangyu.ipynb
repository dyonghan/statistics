# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv("feature_code.csv", index_col=0)

# %%
for r in df.index:
    nums = list()
    end = False
    for i, c in enumerate(df.columns):
        if pd.isnull(df.loc[r,c]):
            end = True
        elif end:
            print('Error: data after end, [{},{}]'.format(r, c))
        elif i%2!=0:
            n = int(df.loc[r,c])
            if not nums:
                nums.append(n)
            elif n == nums[-1] + 1:
                nums.append(n)
            else:
                print('Error: num wrong, [{},{}]'.format(r, c))
print('checked feature code')
# Out:
# checked feature code

# %%
feature_code = dict()
for r in df.index:
    feature_code[r] = dict()
    for i, c in enumerate(df.columns):
        if pd.isnull(df.loc[r,c]):
            break
        elif i%2 == 0:
            k = df.loc[r,c]
        else:
            feature_code[r][k] = int(df.loc[r,c])
print(feature_code)
# Out:
# {'萼片数': {}, '萼片颜色': {'绿': 1, '紫红': 2}, '萼片茸毛': {'无': 0, '有': 1}, '完全开放花冠大小1': {}, '完全开放花冠大小2': {}, '花瓣数': {}, '花瓣颜色': {'白': 1, '微绿': 2, '淡红': 3}, '花瓣茸毛': {'无': 0, '有': 1}, '最大花瓣质地': {'薄': 1, '中': 2, '厚': 3}, '子房茸毛': {'无': 0, '有': 1}, '花柱长度': {}, '花柱头开裂数': {}, '柱头裂位': {'浅': 1, '中': 2, '深': 3, '全': 4}, '雌雄蕊相对高度': {'雌低': 1, '等高': 2, '雌高': 3}, '有无花香': {'无': 0, '有': 1}, '果实形状': {'球': 1, '肾': 2, '三角': 3, '四角': 4, '梅花': 5}, '果实大小1（mm）': {}, '果实大小2（mm）': {}, '果皮中部边缘厚度': {}, '种子形状': {'球': 1, '半球': 2, '锥': 3, '似肾': 4, '不规则': 5}, '种子大小1(mm)': {}, '种子大小2(mm)': {}, '百粒重（g）': {}, '种皮颜色': {'棕色': 1, '棕褐色': 2, '褐色': 3}, '叶长cm': {}, '叶宽cm': {}, '叶面积（cm2）': {}, '叶片大小': {'小': 1, '中': 2, '大': 3, '特大': 4}, '叶脉对数': {}, '叶正面颜色': {'黄绿': 1, '淡绿': 2, '绿': 3, '深绿': 4}, '叶正面隆起性': {'平': 1, '稍隆起': 2, '隆起': 3, '强隆起': 4}, '叶形': {'近圆': 1, '卵形': 2, '椭圆': 3, '长椭圆': 4, '披针形': 5}, '叶身形态': {'稍内折': 1, '内折': 2, '平': 3, '稍背卷': 4}, '叶片质地': {'柔软': 1, '中': 2, '硬': 3}, '叶背茸毛': {'无': 0, '有': 1}, '叶齿密度': {'稀': 1, '中': 2, '密': 3}, '叶齿深度': {'浅': 1, '中': 2, '深': 3}, '叶基形态': {'楔形': 1, '近圆形': 2}, '叶尖形态': {'急尖': 1, '渐尖': 2, '钝尖': 3, '圆尖': 4}, '叶缘形态': {'平': 1, '微波': 2, '波': 3}, '着生状态': {'上斜': 1, '稍上斜': 2, '水平': 3, '下垂': 4}, '树型': {'灌木': 1, '小乔木': 2, '乔木': 3}, '树姿': {'直立': 1, '半开张': 2, '开张': 3}, '1芽2叶芽叶颜色': {'玉白': 1, '黄绿': 2, '淡绿': 3, '绿': 4, '紫绿': 5}, '1芽2叶芽叶茸毛': {'无': 0, '少': 1, '中等': 2, '多': 3, '特多': 4}, '1芽2叶芽长（cm）': {}, '1芽2叶百芽重(g)': {}, '1芽3叶芽长(cm)': {}, '1芽3叶百芽重（g）': {}}

# %%
def to_num(df):
    for r in df.index:
        if not feature_code[r]:
            df.loc[r] = pd.to_numeric(df.loc[r])
        else:
            print(r, feature_code[r])
            df.loc[r] = df.loc[r].apply(lambda x: x if pd.isnull(x) else feature_code[r][x.strip()])
    return df

# %%
shangyu = pd.read_csv("tea-shangyu.csv", index_col=0)
shangyu = to_num(shangyu)
# Out:
# 萼片颜色 {'绿': 1, '紫红': 2}
# 萼片茸毛 {'无': 0, '有': 1}
# 花瓣颜色 {'白': 1, '微绿': 2, '淡红': 3}
# 花瓣茸毛 {'无': 0, '有': 1}
# 最大花瓣质地 {'薄': 1, '中': 2, '厚': 3}
# 子房茸毛 {'无': 0, '有': 1}
# 柱头裂位 {'浅': 1, '中': 2, '深': 3, '全': 4}
# 雌雄蕊相对高度 {'雌低': 1, '等高': 2, '雌高': 3}
# 叶正面颜色 {'黄绿': 1, '淡绿': 2, '绿': 3, '深绿': 4}
# 叶正面隆起性 {'平': 1, '稍隆起': 2, '隆起': 3, '强隆起': 4}
# 叶形 {'近圆': 1, '卵形': 2, '椭圆': 3, '长椭圆': 4, '披针形': 5}
# 叶身形态 {'稍内折': 1, '内折': 2, '平': 3, '稍背卷': 4}
# 叶片质地 {'柔软': 1, '中': 2, '硬': 3}
# 叶背茸毛 {'无': 0, '有': 1}
# 叶基形态 {'楔形': 1, '近圆形': 2}
# 叶尖形态 {'急尖': 1, '渐尖': 2, '钝尖': 3, '圆尖': 4}
# 叶缘形态 {'平': 1, '微波': 2, '波': 3}
# 着生状态 {'上斜': 1, '稍上斜': 2, '水平': 3, '下垂': 4}

# %%
shangyu.loc['完全开放花冠大小1'] = (shangyu.loc['完全开放花冠大小1'] + shangyu.loc['完全开放花冠大小2'])/2
shangyu = shangyu.rename({'完全开放花冠大小1':'完全开放花冠大小'})
shangyu = shangyu.drop(index=['完全开放花冠大小2'])

# %%
keys = ['萼片数','完全开放花冠大小','花瓣数','最大花瓣质地','花柱长度','柱头裂位','雌雄蕊相对高度','着生状态','叶长cm','叶宽cm','叶正面颜色','叶正面隆起性','叶形','叶身形态','叶基形态','叶缘形态']
removed_keys = set(shangyu.index) - set(keys)
shangyu = shangyu.drop(removed_keys)

# %% [markdown]
# ## Correlation

# %%
def crowd(df):
    short_rows = list()
    for r in df.index:
        l = list()
        for c in df.columns:
            if not pd.isnull(df.loc[r,c]):
                l.append(df.loc[r,c])
        if len(l) < 20:
            short_rows.append(r)
        l.extend([np.nan for _ in range(df.shape[1]-len(l))])
        df.loc[r] = l
    return df, short_rows

# %%
df, short_rows = crowd(shangyu)
df = df.drop(short_rows)
print('drop', short_rows)
df.to_csv('results/shangyu_num.csv')
df = df.dropna(axis=1)
df = df.T
# Out:
# drop []

# %%
drop_cols = list()
for c in df.columns:
    if df[c].std() == 0:
        drop_cols.append(c)
print('drop', drop_cols)
df = df.drop(drop_cols, axis=1)
df
# Out:
# drop []
#        萼片数 完全开放花冠大小 花瓣数 最大花瓣质地 花柱长度 柱头裂位 雌雄蕊相对高度 叶长cm 叶宽cm 叶正面颜色 叶正面隆起性 叶形  \
# DXC-1    6      3.4   6      2  1.4    2       3  8.6  2.9     2      1  5
# DXC-2    5      3.7   7      2  1.3    2       2  6.2  3.1     4      2  3
# DXC-3    5      3.9   7      2  1.3    3       2  8.6  3.6     3      1  3
# DXC-4    5      3.6   7      2  1.3    2       2  8.6  3.2     3      2  4
# DXC-5    7      4.1   5      3  1.6    1       2    9  3.1     3      2  4
# DXC-6    5      3.4   7      3  1.1    2       2  8.6  3.2     2      3  4
# DXC-7    5     3.85   7      2  1.3    1       2  6.6  2.6     3      2  3
# DXC-8    5     4.05   6      2  1.4    1       2  6.6  2.4     2      1  4
# DXC-9    6     3.25   7      2  1.3    1       2  7.5  2.4     3      1  5
# DXC-10   5      3.9   7      3  1.4    1       3  7.7  2.7     3      2  4
# DXC-11   5     3.85  10      2  1.2    2       2  9.6  3.8     1      2  4
# DXC-12   5      3.7   8      2  1.2    3       2  8.5  3.7     1      3  4
# DXC-13   5     4.05   6      2  1.3    3       2  6.8  3.3     1      2  3
# DXC-14   5     3.65   7      2    1    2       2  8.5  3.3     1      1  4
# DXC-15   5     3.75   8      2    1    2       3  9.2  3.5     3      3  4
# DXC-16   5     3.65   7      2    1    1       3  7.6  3.1     3      1  4
# DXC-17   5      3.7   7      2  1.2    1       2  6.9  2.6     4      1  4
# DXC-18   5      3.5   9      2  1.1    2       2  8.2    3     1      2  4
# DXC-19   5     3.65   8      2  1.4    1       3  9.1  3.5     3      2  4
# DXC-20   5      3.9   9      2    1    1       3  7.3  3.7     2      2  3
#
#        叶身形态 叶基形态 叶缘形态 着生状态
# DXC-1     3    1    2    1
# DXC-2     3    2    1    1
# DXC-3     1    1    2    1
# DXC-4     2    1    3    1
# DXC-5     2    1    3    1
# DXC-6     3    1    3    1
# DXC-7     3    1    2    1
# DXC-8     1    1    1    1
# DXC-9     2    2    1    1
# DXC-10    3    1    3    1
# DXC-11    1    1    1    2
# DXC-12    3    1    2    1
# DXC-13    3    2    2    1
# DXC-14    1    1    2    1
# DXC-15    3    1    3    1
# DXC-16    2    1    1    1
# DXC-17    2    1    2    1
# DXC-18    2    1    1    1
# DXC-19    2    1    1    1
# DXC-20    3    2    3    3

# %%
df_corr = pd.DataFrame()
for r, row in enumerate(df.columns[1:]):
    for c, col in enumerate(df.columns):
        if r >= c:
            rv, pv = stats.pearsonr(df[col], df[row])
            df_corr.loc[row,col] = ('%.3f*' if pv<=0.05 else '%.3f') % rv
# pd.set_option('precision', 3)
display(df_corr)
# Out:
#               萼片数 完全开放花冠大小      花瓣数  最大花瓣质地    花柱长度     柱头裂位 雌雄蕊相对高度     叶长cm  \
# 完全开放花冠大小   -0.026      NaN      NaN     NaN     NaN      NaN     NaN      NaN
# 花瓣数       -0.519*   -0.175      NaN     NaN     NaN      NaN     NaN      NaN
# 最大花瓣质地      0.384    0.136   -0.339     NaN     NaN      NaN     NaN      NaN
# 花柱长度       0.567*    0.294  -0.570*   0.327     NaN      NaN     NaN      NaN
# 柱头裂位       -0.247   -0.011    0.093  -0.216  -0.155      NaN     NaN      NaN
# 雌雄蕊相对高度    -0.043   -0.056    0.144   0.031  -0.161   -0.336     NaN      NaN
# 叶长cm        0.217   -0.181    0.302   0.193  -0.050    0.252   0.178      NaN
# 叶宽cm       -0.242    0.171   0.526*  -0.135  -0.357   0.550*   0.153   0.581*
# 叶正面颜色       0.142   -0.028   -0.318   0.116   0.279  -0.477*   0.180   -0.285
# 叶正面隆起性     -0.173    0.053    0.325   0.330  -0.154    0.289   0.032    0.298
# 叶形         0.446*  -0.613*   -0.096   0.110   0.118   -0.232   0.172    0.408
# 叶身形态        0.000   -0.128   -0.072   0.228  -0.040    0.046   0.356   -0.249
# 叶基形态        0.049   -0.006    0.000  -0.210  -0.046    0.035  -0.055  -0.531*
# 叶缘形态        0.146    0.202   -0.205  0.548*  -0.023    0.061   0.176    0.229
# 着生状态       -0.123    0.219   0.577*  -0.132  -0.335   -0.161   0.252    0.026
#
#             叶宽cm   叶正面颜色  叶正面隆起性      叶形   叶身形态    叶基形态   叶缘形态
# 完全开放花冠大小     NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 花瓣数          NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 最大花瓣质地       NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 花柱长度         NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 柱头裂位         NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 雌雄蕊相对高度      NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 叶长cm         NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 叶宽cm         NaN     NaN     NaN     NaN    NaN     NaN    NaN
# 叶正面颜色     -0.377     NaN     NaN     NaN    NaN     NaN    NaN
# 叶正面隆起性    0.462*  -0.182     NaN     NaN    NaN     NaN    NaN
# 叶形        -0.331  -0.072  -0.206     NaN    NaN     NaN    NaN
# 叶身形态      -0.012   0.135  0.577*  -0.142    NaN     NaN    NaN
# 叶基形态      -0.012   0.052  -0.037  -0.306  0.326     NaN    NaN
# 叶缘形态       0.182   0.090   0.440  -0.125  0.426  -0.124    NaN
# 着生状态      0.447*  -0.238   0.093  -0.284  0.034   0.367  0.150

# %%
df_corr.to_csv('results/shangyu_corr.csv')

# %% [markdown]
# ## 方差分析

# %%
def avg_std(df):
    avg = df.mean(axis=0)
    std = df.std(axis=0)
    avg_std = pd.concat([avg, std], axis=1, keys=['avg', 'std'])
    avg_std.to_csv('results/shangyu_avg_std.csv')
    display(avg_std)

# %%
def oneway(df):
    size = len(df.keys())
    mx = np.zeros([size,size], np.float32)
    mx = pd.DataFrame(mx, index=df.keys(), columns=df.keys())
    for k1 in df.keys():
        for k2 in df.keys():
            Fv, pv = stats.f_oneway(df[k1], df[k2])
            mx[k1][k2] = pv
    display(mx)
    display('p <= 0.05:')
    df05 = mx<=0.05
    df05.to_csv('results/shangyu_0.05.csv')
    display('p <= 0.01:')
    df01 = mx<=0.01
    df01.to_csv('results/shangyu_0.01.csv')

# %%
avg_std(df)
# Out:
#              avg       std
# 萼片数       5.2000  0.523148
# 完全开放花冠大小  3.7275  0.229114
