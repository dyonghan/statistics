# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv("feature_code.csv", index_col=0)

# %%
for r in df.index:
    nums = list()
    end = False
    for i, c in enumerate(df.columns):
        if pd.isnull(df.loc[r,c]):
            end = True
        elif end:
            print('Error: data after end, [{},{}]'.format(r, c))
        elif i%2!=0:
            n = int(df.loc[r,c])
            if not nums:
                nums.append(n)
            elif n == nums[-1] + 1:
                nums.append(n)
            else:
                print('Error: num wrong, [{},{}]'.format(r, c))
print('checked feature code')
# Out:
# checked feature code

# %%
feature_code = dict()
for r in df.index:
    feature_code[r] = dict()
    for i, c in enumerate(df.columns):
        if pd.isnull(df.loc[r,c]):
            break
        elif i%2 == 0:
            k = df.loc[r,c]
        else:
            feature_code[r][k] = int(df.loc[r,c])
print(feature_code)
# Out:
# {'萼片数': {}, '萼片颜色': {'绿': 1, '紫红': 2}, '萼片茸毛': {'无': 0, '有': 1}, '完全开放花冠大小1': {}, '完全开放花冠大小2': {}, '花瓣数': {}, '花瓣颜色': {'白': 1, '微绿': 2, '淡红': 3}, '花瓣茸毛': {'无': 0, '有': 1}, '最大花瓣质地': {'薄': 1, '中': 2, '厚': 3}, '子房茸毛': {'无': 0, '有': 1}, '花柱长度': {}, '花柱头开裂数': {}, '柱头裂位': {'浅': 1, '中': 2, '深': 3, '全': 4}, '雌雄蕊相对高度': {'雌低': 1, '等高': 2, '雌高': 3}, '有无花香': {'无': 0, '有': 1}, '果实形状': {'球': 1, '肾': 2, '三角': 3, '四角': 4, '梅花': 5}, '果实大小1（mm）': {}, '果实大小2（mm）': {}, '果皮中部边缘厚度': {}, '种子形状': {'球': 1, '半球': 2, '锥': 3, '似肾': 4, '不规则': 5}, '种子大小1(mm)': {}, '种子大小2(mm)': {}, '百粒重（g）': {}, '种皮颜色': {'棕色': 1, '棕褐色': 2, '褐色': 3}, '叶长cm': {}, '叶宽cm': {}, '叶面积（cm2）': {}, '叶片大小': {'小': 1, '中': 2, '大': 3, '特大': 4}, '叶脉对数': {}, '叶正面颜色': {'黄绿': 1, '淡绿': 2, '绿': 3, '深绿': 4}, '叶正面隆起性': {'平': 1, '稍隆起': 2, '隆起': 3, '强隆起': 4}, '叶形': {'近圆': 1, '卵形': 2, '椭圆': 3, '长椭圆': 4, '披针形': 5}, '叶身形态': {'稍内折': 1, '内折': 2, '平': 3, '稍背卷': 4}, '叶片质地': {'柔软': 1, '中': 2, '硬': 3}, '叶背茸毛': {'无': 0, '有': 1}, '叶齿密度': {'稀': 1, '中': 2, '密': 3}, '叶齿深度': {'浅': 1, '中': 2, '深': 3}, '叶基形态': {'楔形': 1, '近圆形': 2}, '叶尖形态': {'急尖': 1, '渐尖': 2, '钝尖': 3, '圆尖': 4}, '叶缘形态': {'平': 1, '微波': 2, '波': 3}, '着生状态': {'上斜': 1, '稍上斜': 2, '水平': 3, '下垂': 4}, '树型': {'灌木': 1, '小乔木': 2, '乔木': 3}, '树姿': {'直立': 1, '半开张': 2, '开张': 3}, '1芽2叶芽叶颜色': {'玉白': 1, '黄绿': 2, '淡绿': 3, '绿': 4, '紫绿': 5}, '1芽2叶芽叶茸毛': {'无': 0, '少': 1, '中等': 2, '多': 3, '特多': 4}, '1芽2叶芽长（cm）': {}, '1芽2叶百芽重(g)': {}, '1芽3叶芽长(cm)': {}, '1芽3叶百芽重（g）': {}}

# %%
def to_num(df):
    for r in df.index:
        if not feature_code[r]:
            df.loc[r] = pd.to_numeric(df.loc[r])
        else:
            print(r, feature_code[r])
            df.loc[r] = df.loc[r].apply(lambda x: x if pd.isnull(x) else feature_code[r][x.strip()])
            print('done')
    return df

# %%
tiantai = pd.read_csv("tea-tiantai.csv", index_col=0)
tiantai = to_num(tiantai)
# Out:
# 萼片颜色 {'绿': 1, '紫红': 2}
# done
# 萼片茸毛 {'无': 0, '有': 1}
# done
# 花瓣颜色 {'白': 1, '微绿': 2, '淡红': 3}
# done
# 花瓣茸毛 {'无': 0, '有': 1}
# done
# 最大花瓣质地 {'薄': 1, '中': 2, '厚': 3}
# done
# 子房茸毛 {'无': 0, '有': 1}
# done
# 柱头裂位 {'浅': 1, '中': 2, '深': 3, '全': 4}
# done
# 雌雄蕊相对高度 {'雌低': 1, '等高': 2, '雌高': 3}
# done
# 叶正面颜色 {'黄绿': 1, '淡绿': 2, '绿': 3, '深绿': 4}
# done
# 叶正面隆起性 {'平': 1, '稍隆起': 2, '隆起': 3, '强隆起': 4}
# done
# 叶形 {'近圆': 1, '卵形': 2, '椭圆': 3, '长椭圆': 4, '披针形': 5}
# done
# 叶身形态 {'稍内折': 1, '内折': 2, '平': 3, '稍背卷': 4}
# done
# 叶片质地 {'柔软': 1, '中': 2, '硬': 3}
# done
# 叶背茸毛 {'无': 0, '有': 1}
# done
# 叶基形态 {'楔形': 1, '近圆形': 2}
# done
# 叶尖形态 {'急尖': 1, '渐尖': 2, '钝尖': 3, '圆尖': 4}
# done
# 叶缘形态 {'平': 1, '微波': 2, '波': 3}
# done
# 着生状态 {'上斜': 1, '稍上斜': 2, '水平': 3, '下垂': 4}
# done

# %%
tiantai.loc['完全开放花冠大小1'] = (tiantai.loc['完全开放花冠大小1'] + tiantai.loc['完全开放花冠大小2'])/2
tiantai = tiantai.rename({'完全开放花冠大小1':'完全开放花冠大小'})
tiantai = tiantai.drop(index=['完全开放花冠大小2'])

# %%
keys = ['萼片数','完全开放花冠大小','花瓣数','最大花瓣质地','花柱长度','柱头裂位','雌雄蕊相对高度','着生状态','叶长cm','叶宽cm','叶正面颜色','叶正面隆起性','叶形','叶身形态','叶基形态','叶缘形态']
removed_keys = set(tiantai.index) - set(keys)
tiantai = tiantai.drop(removed_keys)

# %% [markdown]
# ## Correlation

# %%
def crowd(df):
    short_rows = list()
    for r in df.index:
        l = list()
        for c in df.columns:
            if not pd.isnull(df.loc[r,c]):
                l.append(df.loc[r,c])
        if len(l) < 20:
            short_rows.append(r)
        l.extend([np.nan for _ in range(df.shape[1]-len(l))])
        df.loc[r] = l
    return df, short_rows

# %%
df, short_rows = crowd(tiantai)
df = df.drop(short_rows)
print('drop', short_rows)
df.to_csv('results/tiantai_num.csv')
df = df.dropna(axis=1)
df = df.T
# Out:
# drop []

# %%
drop_cols = list()
for c in df.columns:
    if df[c].std() == 0:
        drop_cols.append(c)
print('drop', drop_cols)
df = df.drop(drop_cols, axis=1)
df
# Out:
# drop []
#        萼片数 完全开放花冠大小 花瓣数 最大花瓣质地 花柱长度 柱头裂位 雌雄蕊相对高度  叶长cm 叶宽cm 叶正面颜色 叶正面隆起性 叶形  \
# YSA-1    5      4.1   8      2  1.3    2       2     9  4.7     4      3  3
# YSA-2    5      4.6   8      2  1.1    1       2  10.5  4.5     4      2  4
# YSA-3    5      3.8   7      2  1.3    1       3  10.5  4.4     3      2  4
# YSA-4    5      3.5   7      1  0.9    3       1   8.7  3.9     3      2  4
# YSA-5    5      3.7   6      2  1.1    1       2   9.1  4.6     3      3  3
# YSA-6    5     3.65  12      2  1.2    2       2  12.4  4.1     3      1  5
# YSA-7    5      3.8   7      2  1.2    2       1   7.7  4.4     4      3  3
# YSA-8    5     3.65  11      2    1    1       2   8.6  4.1     3      2  3
# YSA-9    5     3.55   6      2  1.3    1       3   7.5  3.8     3      2  3
# YSA-10   5     3.85   8      3  1.3    1       3  11.5  4.8     3      2  4
# YSA-11   5     5.35   6      3  1.2    2       2   8.6  4.1     4      3  3
# YSA-12   4     4.05   7      2  1.3    3       2   9.5  4.4     3      2  3
# YSA-13   5      3.5   9      2  1.2    2       3  12.9  5.4     4      2  4
# YSA-14   5      3.7   7      2  1.2    3       2   7.6  2.9     2      2  4
# YSA-15   5      3.6   8      2  1.2    1       3   7.7  3.7     4      2  4
# YSA-16   5      3.9   7      1  1.3    2       3   8.3  3.5     4      3  4
# YSA-17   5     3.65   7      2  1.2    2       2   9.6  3.4     2      2  3
# YSA-18   5      3.7   6      2  1.3    2       2   9.1  4.1     4      3  3
# YSA-19   5     3.65   8      1  1.2    2       2   8.2  4.1     3      3  3
# YSA-20   5      3.5   9      1  1.3    3       3   9.3    4     3      2  3
#
#        叶身形态 叶基形态 叶缘形态 着生状态
# YSA-1     3    2    2    2
# YSA-2     3    1    2    2
# YSA-3     3    1    2    2
# YSA-4     3    2    1    3
# YSA-5     3    2    1    2
# YSA-6     3    1    1    3
# YSA-7     3    2    1    2
# YSA-8     3    2    1    2
# YSA-9     3    2    2    2
# YSA-10    3    1    2    3
# YSA-11    3    1    1    1
# YSA-12    1    2    2    1
# YSA-13    1    1    2    2
# YSA-14    1    1    2    1
# YSA-15    3    2    1    1
# YSA-16    1    2    1    1
# YSA-17    1    1    2    2
# YSA-18    1    1    2    1
# YSA-19    3    2    2    1
# YSA-20    1    1    2    1

# %%
df_corr = pd.DataFrame()
for r, row in enumerate(df.columns[1:]):
    for c, col in enumerate(df.columns):
        if r >= c:
            rv, pv = stats.pearsonr(df[col], df[row])
            df_corr.loc[row,col] = ('%.3f*' if pv<=0.05 else '%.3f') % rv
# pd.set_option('precision', 3)
display(df_corr)
# Out:
#              萼片数 完全开放花冠大小      花瓣数  最大花瓣质地    花柱长度     柱头裂位 雌雄蕊相对高度     叶长cm  \
# 完全开放花冠大小  -0.112      NaN      NaN     NaN     NaN      NaN     NaN      NaN
# 花瓣数        0.103   -0.256      NaN     NaN     NaN      NaN     NaN      NaN
# 最大花瓣质地    -0.043   0.505*   -0.096     NaN     NaN      NaN     NaN      NaN
# 花柱长度      -0.203    0.056   -0.201   0.182     NaN      NaN     NaN      NaN
# 柱头裂位      -0.363   -0.077   -0.040  -0.422   0.010      NaN     NaN      NaN
# 雌雄蕊相对高度    0.092   -0.150    0.078   0.075  0.581*   -0.359     NaN      NaN
# 叶长cm      -0.028   -0.025   0.492*   0.261   0.077   -0.108   0.252      NaN
# 叶宽cm      -0.109    0.118    0.172   0.292   0.048   -0.290   0.086   0.623*
# 叶正面颜色      0.107    0.394   -0.060   0.087   0.124   -0.226   0.063    0.037
# 叶正面隆起性     0.124    0.317  -0.590*  -0.067   0.143   -0.012  -0.216  -0.494*
# 叶形         0.194   -0.128    0.436   0.000  -0.118   -0.058   0.204   0.525*
# 叶身形态       0.313    0.215    0.128   0.253  -0.357  -0.585*  -0.211   -0.076
# 叶基形态      -0.229   -0.210   -0.129  -0.371  -0.233   -0.069  -0.241  -0.587*
# 叶缘形态      -0.187   -0.102   -0.158   0.038  0.514*    0.112   0.328    0.232
# 着生状态       0.246   -0.209    0.346   0.199  -0.384   -0.271  -0.201   0.517*
#
#             叶宽cm   叶正面颜色   叶正面隆起性      叶形    叶身形态    叶基形态    叶缘形态
# 完全开放花冠大小     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 花瓣数          NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 最大花瓣质地       NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 花柱长度         NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 柱头裂位         NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 雌雄蕊相对高度      NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 叶长cm         NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 叶宽cm         NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 叶正面颜色     0.470*     NaN      NaN     NaN     NaN     NaN     NaN
# 叶正面隆起性     0.089  0.449*      NaN     NaN     NaN     NaN     NaN
# 叶形        -0.024   0.000  -0.607*     NaN     NaN     NaN     NaN
# 叶身形态       0.257   0.180    0.019   0.089     NaN     NaN     NaN
# 叶基形态      -0.047   0.156    0.359  -0.338   0.314     NaN     NaN
# 叶缘形态       0.144  -0.255   -0.110  -0.173  -0.385  -0.408     NaN
# 着生状态       0.363  -0.168  -0.450*   0.424  0.488*  -0.072  -0.146

# %%
df_corr.to_csv('results/tiantai_corr.csv')

# %% [markdown]
# ## 方差分析

# %%
def avg_std(df):
    avg = df.mean(axis=0)
    std = df.std(axis=0)
    avg_std = pd.concat([avg, std], axis=1, keys=['avg', 'std'])
    avg_std.to_csv('results/tiantai_avg_std.csv')
    display(avg_std)

# %%
def oneway(df):
    size = len(df.keys())
    mx = np.zeros([size,size], np.float32)
    mx = pd.DataFrame(mx, index=df.keys(), columns=df.keys())
    for k1 in df.keys():
        for k2 in df.keys():
            Fv, pv = stats.f_oneway(df[k1], df[k2])
            mx[k1][k2] = pv
    display(mx)
    display('p <= 0.05:')
    df05 = mx<=0.05
    df05.to_csv('results/tiantai_0.05.csv')
    display('p <= 0.01:')
    df01 = mx<=0.01
    df01.to_csv('results/tiantai_0.01.csv')

# %%
avg_std(df)
# Out:
#             avg       std
# 萼片数       4.950  0.223607
